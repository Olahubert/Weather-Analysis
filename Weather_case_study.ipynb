# %%
Weather=pd.read_csv('Weather_Dataset.csv')

# %%
Weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
import pandas as pd

# %%
Weather.shape
# Out:
# (8784, 8)

# %%
Weather.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
Weather["Weather"]
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object

# %%
Weather1=Weather["Weather"]

# %%
Weather1.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
Weather1.nunique()
# Out:
# 50

# %%
Weather.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
Weather.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
Weather1.count()
# Out:
# 8784

# %%
Weather1.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#Find all the unique “wind speed” values in the data

# %%
Weather['Wind Speed_km/h']
# Out:
# 0        4
# 1        4
# 2        7
# 3        6
# 4        7
#         ..
# 8779    30
# 8780    24
# 8781    28
# 8782    28
# 8783    30
# Name: Wind Speed_km/h, Length: 8784, dtype: int64

# %%
wind_speed=Weather['Wind Speed_km/h']

# %%
wind_speed.unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
#Find the number of times when the “weather is exactly clear”

# %%
Weather1.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
Weather1 == "Clear"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
Clear1=Weather1 == "Clear"

# %%
Weather.loc[Clear1]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#Find the number of times when the “weather is Mainly Clear”

# %%
Weather1 == "Mainly Clear"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
Mainly_Clear1=Weather1 == "Mainly Clear"

# %%
Weather.loc[Mainly_Clear1]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 36      1/2/2012 12:00     1.7              -6.2         56               48
# 60      1/3/2012 12:00   -14.9             -22.6         52               20
# 61      1/3/2012 13:00   -15.1             -22.4         54               22
# 62      1/3/2012 14:00   -14.9             -22.9         50               22
# 63      1/3/2012 15:00   -14.8             -22.2         53               19
# ...                ...     ...               ...        ...              ...
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8757  12/30/2012 21:00   -13.8             -16.5         80               20
# 8758  12/30/2012 22:00   -13.7             -16.3         81               19
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
#Find the number of times when the “windspeed was exactly 4km/h”

# %%
wind_speed == 4
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Wind Speed_km/h, Length: 8784, dtype: bool

# %%
Weather.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
speed=wind_speed == 4

# %%
speed
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Wind Speed_km/h, Length: 8784, dtype: bool

# %%
Weather.loc[speed]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
null_count=Weather.isnull().sum()

# %%
null_count
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#dropna will remove the role that cointains missing value

# %%
#Weather.isna().sum() can also work

# %%
#Rename the column name “Weather” in the dataframe to “Weather_Condition”

# %%
Weather.rename(columns = {"Weather":"Weather_Condition"},inplace=True)

# %%
Weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#Show all records where the weather condition is fog

# %%
Weather["Weather_Condition"]
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather_Condition, Length: 8784, dtype: object

# %%
Weather_Condition1=Weather["Weather_Condition"]

# %%
Weather_Condition1.value_counts()
# Out:
# Weather_Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
Weather_Condition1 == "Fog"
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather_Condition, Length: 8784, dtype: bool

# %%
Weather.loc[Weather_Condition1 == "Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
#What is the mean “Visibility”

# %%
Mean_Visibility=Weather['Visibility_km'].mean()

# %%
round(Weather['Visibility_km'].mean(),3)  #round function
# Out:
# 27.664

# %%
Mean_Visibility
# Out:
# 27.664446721311478

# %% [markdown]
# #What is the standard deviation of “pressure” in the dataset

# %%
#What is the standard deviation of “pressure” in the dataset

# %%
Weather['Press_kPa']
# Out:
# 0       101.24
# 1       101.24
# 2       101.26
# 3       101.27
# 4       101.23
#          ...
# 8779    100.13
# 8780    100.03
# 8781     99.95
# 8782     99.91
# 8783     99.89
# Name: Press_kPa, Length: 8784, dtype: float64

# %%
Standard_deviation=Weather['Press_kPa'].std()

# %%
round(Weather['Press_kPa'].std(), 2)    #round function
# Out:
# 0.84

# %%
Standard_deviation
# Out:
# 0.8440047459486474

# %%
#What is the variance of the “relative humidity” in the data

# %%
Weather['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
round(Weather['Rel Hum_%'].var(),2)
# Out:
# 286.25

# %%
#Find all instance when “snow” was recorded

# %%
Weather_Condition1.value_counts()
# Out:
# Weather_Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
Weather[Weather_Condition1 == "Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#Find all the instances when “Wind speed is above 24” and “visibility is above 25”

# %%
speed1=wind_speed > 24

# %%
Visibility= Weather['Visibility_km']

# %%
Visibility_above=Visibility > 25

# %%
Weather[speed1 & Visibility_above]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 111     1/5/2012 15:00    -4.3             -12.0         55               26
# 350    1/15/2012 14:00   -16.0             -23.4         53               26
# 422    1/18/2012 14:00   -10.3             -17.6         55               28
# 423    1/18/2012 15:00   -10.4             -18.0         54               30
# ...                ...     ...               ...        ...              ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
#
# ...

# %%
#We can also use the loc function        Weather.loc[speed1 & Visisbility_above]

# %%
#What is the mean value of each column against each “Weather Conditions”
Weather.groupby('Weather_Condition').first()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                      1/3/2012 19:00   -16.9
# Cloudy                                     1/1/2012 17:00     3.0
# Drizzle                                   1/23/2012 21:00     3.3
# Drizzle,Fog                               1/23/2012 20:00     2.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     1.0
# Fog                                         1/1/2012 0:00    -1.8
# Freezing Drizzle                           1/7/2012 11:00    -5.4
# Freezing Drizzle,Fog                        1/1/2012 2:00    -1.8
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -4.5
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
Group=Weather.groupby('Weather_Condition').first()

# %%
#Group['Temp_C'].mean()

# %%
Tem_mean=Group['Temp_C'].mean()

# %%
Tem_mean
# Out:
# 0.8980000000000001

# %%
Dem_mean=Group['Dew Point Temp_C'].mean()   
Dem_mean
# Out:
# -1.858

# %%
Rel_mean=Group['Rel Hum_%'].mean()

# %%
Rel_mean
# Out:
# 82.36

# %%
Wind_mean=Group['Wind Speed_km/h'].mean() 
Wind_mean
# Out:
# 18.02

# %%
Visible_mean=Group['Visibility_km'].mean() 
Visible_mean
# Out:
# 10.075999999999999

# %%
Press_mean=Group['Press_kPa'].mean() 
Press_mean
# Out:
# 100.35359999999999

# %%
#another method

# %%
Group[['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%']].mean()
# Out:
# Temp_C               0.898
# Dew Point Temp_C    -1.858
# Rel Hum_%           82.360
# dtype: float64

# %%
#What is the minimum and maximum value of each column against each “weather condition”

# %%
Group[["Temp_C","Dew Point Temp_C","Rel Hum_%", "Wind Speed_km/h","Visibility_km","Press_kPa"]].max()
# Out:
# Temp_C               26.70
# Dew Point Temp_C     20.10
# Rel Hum_%            97.00
# Wind Speed_km/h      48.00
# Visibility_km        25.00
# Press_kPa           102.97
# dtype: float64

# %%
Group[["Temp_C","Dew Point Temp_C","Rel Hum_%", "Wind Speed_km/h","Visibility_km","Press_kPa"]].min()
# Out:
# Temp_C             -19.00
# Dew Point Temp_C   -24.80
# Rel Hum_%           50.00
# Wind Speed_km/h      0.00
# Visibility_km        0.60
# Press_kPa           98.56
# dtype: float64

# %%
#Find all instances when “Weather is clear” or “Relative humidity is above 40”

# %%
Weather[Weather_Condition1 == "Clear"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
[Weather_Condition1 == "Clear"]
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  8779    False
#  8780    False
#  8781    False
#  8782    False
#  8783    False
#  Name: Weather_Condition, Length: 8784, dtype: bool]

# %%
Weather["Rel Hum_%"]
# Out:
# 0       86
# 1       87
# 2       89
# 3       88
# 4       88
#         ..
# 8779    81
# 8780    83
# 8781    93
# 8782    89
# 8783    86
# Name: Rel Hum_%, Length: 8784, dtype: int64

# %%
Relative_humidity=[Weather["Rel Hum_%"] >40]

# %%
Relative_humidity
# Out:
# [0       True
#  1       True
#  2       True
#  3       True
#  4       True
#          ...
#  8779    True
#  8780    True
#  8781    True
#  8782    True
#  8783    True
#  Name: Rel Hum_%, Length: 8784, dtype: bool]

# %%
we = Weather['Weather_Condition'] == "Clear"
rel = Weather["Rel Hum_%"] > 40
Weather[we | rel]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
Find all instances when “Weather is clear” and “Relative humidity is above 40 ” or “Visibility is above 40”

# %%
 vis=Weather["Visibility_km"] > 40

# %%
Weather[we & rel | vis]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
#Change a row in a column  
tip.iloc[50]['total_bill'] = ' '
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Change a row in a column
# ----> 2 tip.iloc[50]['total_bill'] = ' '
#
# NameError: name 'tip' is not defined
